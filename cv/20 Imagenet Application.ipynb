# %% [markdown]
# ##### Import the libraries

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D

# %% [markdown]
# ##### Build the CNN

# %%
def build_cnn(input_shape=(224, 224, 3), num_classes=10):
    model = Sequential()
    model.add(Conv2D(32, (3, 3),activation='relu', 
                   input_shape=input_shape))
    model.add(MaxPool2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPool2D((2, 2)))
    model.add(Flatten())
    model.add(Dense(num_classes, activation='softmax'))
    return model

# %%
model = build_cnn(input_shape=(64,64,3))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 31, 31, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 14, 14, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 10)                125450
#
# =================================================================
# Total params: 144842 (565.79 KB)
# Trainable params: 144842 (565.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ##### Create the image data generators

# %%
train_datagen = ImageDataGenerator(
    rescale=1/255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

# %%
test_datagen = ImageDataGenerator(rescale=1/255)

# %%
train_dataset = train_datagen.flow_from_directory(
    'imagenet-new/train/',
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical')
# Out:
# Found 5000 images belonging to 10 classes.

# %%
test_dataset = test_datagen.flow_from_directory(
    'imagenet-new/test/',
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical')
# Out:
# Found 10000 images belonging to 1 classes.

# %%
train_dataset.class_indices
# Out:
# {'crocodile': 0,
#  'fish': 1,
#  'fossils': 2,
#  'frog': 3,
#  'insect': 4,
#  'reptiles': 5,
#  'scorpion': 6,
#  'snake': 7,
#  'spider': 8,
#  'toad': 9}

# %% [markdown]
# ##### Compile the model

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ##### Train the model

# %%
model.fit(train_dataset, epochs=30, batch_size=10)
# Out:
# Epoch 1/30
# 157/157 [==============================] - 17s 110ms/step - loss: 0.6883 - accuracy: 0.7694
# Epoch 2/30
# 157/157 [==============================] - 17s 109ms/step - loss: 0.6677 - accuracy: 0.7748
# Epoch 3/30
# 157/157 [==============================] - 17s 110ms/step - loss: 0.6410 - accuracy: 0.7886
# Epoch 4/30
# 157/157 [==============================] - 17s 110ms/step - loss: 0.6162 - accuracy: 0.7960
# Epoch 5/30
# 157/157 [==============================] - 17s 108ms/step - loss: 0.6054 - accuracy: 0.7918
# Epoch 6/30
# 157/157 [==============================] - 17s 108ms/step - loss: 0.6047 - accuracy: 0.7930
# Epoch 7/30
# 157/157 [==============================] - 17s 110ms/step - loss: 0.5889 - accuracy: 0.7984
# Epoch 8/30
# 157/157 [==============================] - 17s 109ms/step - loss: 0.5861 - accuracy: 0.8012
# Epoch 9/30
# 157/157 [==============================] - 17s 110ms/step - loss: 0.5569 - accuracy: 0.8144
# Epoch 10/30
# 157/157 [==============================] - 17s 109ms/step - loss: 0.5420 - accuracy: 0.8120
# Epoch 11/30
# 157/157 [==============================] - 17s 110ms/step - loss: 0.5586 - accuracy: 0.8096
# Epoch 12/30
# 157/157 [==============================] - 16s 102ms/step - loss: 0.5335 - accuracy: 0.8204
# Epoch 13/30
# 157/157 [==============================] - 16s 102ms/step - loss: 0.5137 - accuracy: 0.8200
# Epoch 14/30
# 157/157 [==============================] - 16s 103ms/step - loss: 0.5249 - accuracy: 0.8250
# Epoch 15/30
# 157/157 [==============================] - 16s 102ms/step - loss: 0.5039 - accuracy: 0.8330
# Epoch 16/30
# 157/157 [==============================] - 16s 103ms/step - loss: 0.4994 - accuracy: 0.8366
# Epoch 17/30
# 157/157 [==============================] - 16s 104ms/step - loss: 0.4928 - accuracy: 0.8338
# Epoch 18/30
# 157/157 [==============================] - 16s 104ms/step - loss: 0.4829 - accuracy: 0.8348
# Epoch 19/30
# 157/157 [==============================] - 16s 102ms/step - loss: 0.4709 - accuracy: 0.8490
# Epoch 20/30
# 157/157 [==============================] - 16s 104ms/step - loss: 0.4586 - accuracy: 0.8426
# Epoch 21/30
# 157/157 [==============================] - 17s 106ms/step - loss: 0.4359 - accuracy: 0.8504
# Epoch 22/30
# 157/157 [==============================] - 17s 110ms/step - loss: 0.4633 - accuracy: 0.8420
# Epoch 23/30
# 157/157 [==============================] - 17s 108ms/step - loss: 0.4425 - accuracy: 0.8502
# Epoch 24/30
# 157/157 [==============================] - 16s 104ms/step - loss: 0.4179 - accuracy: 0.8608
# Epoch 25/30
# 157/157 [==============================] - 16s 104ms/step - loss: 0.4351 - accuracy: 0.8528
# Epoch 26/30
# 157/157 [==============================] - 16s 104ms/step - loss: 0.4151 - accuracy: 0.8568
# Epoch 27/30
# 157/157 [==============================] - 16s 104ms/step - loss: 0.4093 - accuracy: 0.8618
# Epoch 28/30
# 157/157 [==============================] - 16s 102ms/step - loss: 0.4154 - accuracy: 0.8534
# Epoch 29/30
# 157/157 [==============================] - 16s 104ms/step - loss: 0.4022 - accuracy: 0.8616
# Epoch 30/30
# 157/157 [==============================] - 16s 104ms/step - loss: 0.3913 - accuracy: 0.8634

# %% [markdown]
# ##### Label the unlabeled data

# %%
import os
mypath = '/home/mitu/nlpcv-jun24/cv/imagenet-new/test/images/'

# %%
for file in os.listdir(mypath):
    image = plt.imread(mypath + file)
    if len(image.shape) == 3:
        image = image.reshape(1,64,64,3)
        result = model.predict(image, verbose=False)
        if result.argmax() == 1:
            print(file)
# Out:
# test_386.JPEG
# test_9611.JPEG
# test_4025.JPEG
# test_1424.JPEG
# test_5739.JPEG
# test_917.JPEG
# test_3754.JPEG
# test_3121.JPEG
# test_1265.JPEG
# test_1665.JPEG
# test_8949.JPEG
# test_6297.JPEG
# test_1168.JPEG
# test_840.JPEG
# test_1273.JPEG
# test_4354.JPEG
# test_3176.JPEG
# test_9683.JPEG
# test_9667.JPEG
# test_2637.JPEG
# test_3088.JPEG
# test_2020.JPEG
# test_3611.JPEG
# test_5843.JPEG
# test_9459.JPEG
# test_2548.JPEG
# test_4059.JPEG
# test_5796.JPEG
# test_2807.JPEG
# test_1267.JPEG
# test_1454.JPEG
# test_3796.JPEG
# test_2287.JPEG
# test_2690.JPEG
# test_8236.JPEG
# test_529.JPEG
# test_4034.JPEG
# test_6173.JPEG
# test_6574.JPEG
# test_7227.JPEG
# test_264.JPEG
# test_7923.JPEG
# test_3927.JPEG
# test_1574.JPEG
# test_4714.JPEG
# test_5574.JPEG
# test_740.JPEG
# test_1426.JPEG
# test_6378.JPEG
# test_4763.JPEG
# test_9776.JPEG
# test_1466.JPEG
# test_4776.JPEG
# test_8163.JPEG
# test_7743.JPEG
# test_5230.JPEG
# test_7807.JPEG
# test_2765.JPEG
# test_4711.JPEG
# test_6339.JPEG
# test_5336.JPEG
# test_7730.JPEG
# test_2523.JPEG
# test_3468.JPEG
# test_6594.JPEG
# test_564.JPEG
# test_355.JPEG
# test_5396.JPEG
# test_852.JPEG
# test_8670.JPEG
# test_6859.JPEG
# test_2977.JPEG
# test_3044.JPEG
# test_7882.JPEG
# test_5886.JPEG
# test_5786.JPEG
# test_9422.JPEG
# test_3165.JPEG
# test_8800.JPEG
# test_6112.JPEG
# test_146.JPEG
# test_3295.JPEG
# test_1008.JPEG
# test_8425.JPEG
# test_6513.JPEG
# test_2023.JPEG
# test_8635.JPEG
# test_1707.JPEG
# test_2155.JPEG
# test_5285.JPEG
# test_5905.JPEG
# test_1122.JPEG
# test_2306.JPEG
# test_6646.JPEG
# test_8316.JPEG
# test_4511.JPEG
# test_5682.JPEG
# test_9318.JPEG
# test_532.JPEG
# test_3113.JPEG
# test_4353.JPEG
# test_9665.JPEG
# test_1690.JPEG
# test_644.JPEG
# test_5447.JPEG
# test_8052.JPEG
# test_11.JPEG
# test_8384.JPEG
# test_3266.JPEG
# test_3287.JPEG
# test_1964.JPEG
# test_7855.JPEG
# test_8145.JPEG
# test_4251.JPEG
# test_7424.JPEG
# test_4661.JPEG
# test_6317.JPEG
# test_9946.JPEG
# test_7540.JPEG
# test_9970.JPEG
# test_6185.JPEG
# test_6953.JPEG
# test_3050.JPEG
# test_3742.JPEG
# test_9174.JPEG
# test_3234.JPEG
# test_5803.JPEG
# test_2217.JPEG
# test_3811.JPEG
# test_4750.JPEG
# test_4155.JPEG
# test_3903.JPEG
# test_4389.JPEG
# test_3730.JPEG
# test_4878.JPEG
# test_7448.JPEG
# test_1071.JPEG
# test_850.JPEG
# test_8986.JPEG
# test_8.JPEG
# test_6784.JPEG
# test_1053.JPEG
# test_1309.JPEG
# test_5143.JPEG
# test_5847.JPEG
# test_6108.JPEG
# test_1076.JPEG
# test_5381.JPEG
# test_8538.JPEG
# test_2550.JPEG
# test_6634.JPEG
# test_5888.JPEG
# test_7120.JPEG
# test_6957.JPEG
# test_7091.JPEG
# test_1206.JPEG
# test_3760.JPEG
# test_5946.JPEG
# test_7933.JPEG
# test_8728.JPEG
# test_6470.JPEG
# test_6562.JPEG
# test_1729.JPEG
# test_1863.JPEG
# test_5349.JPEG
# test_157.JPEG
# test_498.JPEG
# test_6253.JPEG
# test_1413.JPEG
# test_3583.JPEG
# test_9025.JPEG
# test_2264.JPEG
# test_2859.JPEG
# test_8379.JPEG
# test_7530.JPEG
# test_394.JPEG
# test_2273.JPEG
# test_1744.JPEG
# test_9461.JPEG
# test_9926.JPEG
# test_5760.JPEG
# test_4049.JPEG
# test_5959.JPEG
# test_6141.JPEG
# test_3739.JPEG
# test_3518.JPEG
# test_9940.JPEG
# test_6560.JPEG
# test_240.JPEG
# test_1478.JPEG
# test_4420.JPEG
# test_4629.JPEG
# test_7027.JPEG
# test_2006.JPEG
# test_4038.JPEG
# test_6123.JPEG
# test_4682.JPEG
# test_5438.JPEG
# test_6231.JPEG
# test_7995.JPEG
# test_2182.JPEG
# test_4447.JPEG
# test_6748.JPEG
# test_8994.JPEG
# test_4075.JPEG
# test_3110.JPEG
# test_3871.JPEG
# test_3681.JPEG
# test_9834.JPEG
# test_6696.JPEG
# test_5845.JPEG
# test_5779.JPEG
# test_1320.JPEG
# test_9088.JPEG
# test_9674.JPEG
# test_8229.JPEG
# test_2543.JPEG
# test_3435.JPEG
# test_6861.JPEG
# test_2249.JPEG
# test_1993.JPEG
# test_4802.JPEG
# test_4766.JPEG
# test_7880.JPEG
# test_3999.JPEG
# test_6262.JPEG
# test_4733.JPEG
# test_2481.JPEG
# test_9685.JPEG
# test_3386.JPEG
# test_2633.JPEG
# test_3838.JPEG
# test_8278.JPEG
# test_4387.JPEG
# test_8440.JPEG
# test_9555.JPEG
# test_3960.JPEG
# test_6468.JPEG
# test_1313.JPEG
# test_404.JPEG
# test_3723.JPEG
# test_7606.JPEG
# test_3323.JPEG
# test_8289.JPEG
# test_4919.JPEG
# test_3390.JPEG
# test_344.JPEG
# test_6407.JPEG
# test_2782.JPEG
# test_5093.JPEG
# test_6159.JPEG
# test_4931.JPEG
# test_951.JPEG
# test_8815.JPEG
# test_4326.JPEG
# test_8315.JPEG
# test_6888.JPEG
# test_2582.JPEG
# test_7241.JPEG
# test_7401.JPEG
# test_6980.JPEG
# test_6101.JPEG
# test_7587.JPEG
# test_2919.JPEG
# test_5592.JPEG
# test_4972.JPEG
# test_3120.JPEG
# test_4295.JPEG
# test_5448.JPEG
# test_5759.JPEG
# test_3202.JPEG
# test_9741.JPEG
# test_6103.JPEG
# test_9267.JPEG
# test_4027.JPEG
# test_2772.JPEG
# test_6741.JPEG
# test_7319.JPEG
# test_1417.JPEG
# test_6221.JPEG
# test_3963.JPEG
# test_3726.JPEG
# test_5385.JPEG
# test_6913.JPEG
# test_9107.JPEG
# test_9201.JPEG
# test_5250.JPEG
# test_7177.JPEG
# test_9552.JPEG
# test_4556.JPEG
# test_3826.JPEG
# test_9793.JPEG
# test_3798.JPEG
# test_7627.JPEG
# test_5317.JPEG
# test_8652.JPEG
# test_5341.JPEG
# test_6505.JPEG
# test_5756.JPEG
# test_6051.JPEG
# test_7042.JPEG
# test_3865.JPEG
# test_1781.JPEG
# test_800.JPEG
# test_2851.JPEG
# test_4110.JPEG
# test_3924.JPEG
# test_5948.JPEG
# test_6806.JPEG
# test_458.JPEG
# test_6785.JPEG
# test_9758.JPEG
# test_5086.JPEG
# test_4542.JPEG
# test_2607.JPEG
# test_4603.JPEG
# test_9908.JPEG
# test_6220.JPEG
# test_1178.JPEG
# test_516.JPEG
# test_6139.JPEG
# test_8552.JPEG
# test_2576.JPEG
# test_2362.JPEG
# test_6999.JPEG
# test_1047.JPEG
# test_7157.JPEG
# test_7359.JPEG
# test_5181.JPEG
# test_6756.JPEG
# test_1614.JPEG
# test_3312.JPEG
# test_2522.JPEG
# test_5696.JPEG
# test_7667.JPEG
# test_4815.JPEG
# test_6684.JPEG
# test_2485.JPEG
# test_7961.JPEG
# test_9633.JPEG
# test_8993.JPEG
# test_8436.JPEG
# test_4898.JPEG
# test_692.JPEG
# test_3095.JPEG
# test_6307.JPEG
# test_5415.JPEG
# test_3841.JPEG
# test_3656.JPEG
# test_952.JPEG
# test_3289.JPEG
# test_5264.JPEG
# test_3150.JPEG
# test_2372.JPEG
# test_758.JPEG
# test_7737.JPEG
# test_9498.JPEG
# test_6866.JPEG
# test_9706.JPEG
# test_1693.JPEG
# test_4078.JPEG
# test_3895.JPEG
# test_701.JPEG
# test_1801.JPEG
# test_9479.JPEG
# test_5475.JPEG
# test_3187.JPEG
# test_7431.JPEG
# test_8085.JPEG
# test_6178.JPEG
# test_6096.JPEG
# test_7577.JPEG
# test_5382.JPEG
# test_9005.JPEG
# test_302.JPEG
# test_7578.JPEG
# test_8134.JPEG
# test_2959.JPEG
# test_7576.JPEG
# test_9966.JPEG
# test_4138.JPEG
# test_9167.JPEG
# test_6823.JPEG
# test_7702.JPEG
# test_230.JPEG
# test_3595.JPEG
# test_7752.JPEG
# test_6810.JPEG
# test_7876.JPEG
# test_4102.JPEG
# test_1007.JPEG
# test_390.JPEG
# test_7385.JPEG
# test_3692.JPEG
# test_9976.JPEG
# test_2214.JPEG
# test_206.JPEG
# test_7498.JPEG
# test_927.JPEG
# test_1668.JPEG
# test_8565.JPEG
# test_9514.JPEG
# test_7869.JPEG
# test_3741.JPEG
# test_9447.JPEG
# test_9896.JPEG
# test_4899.JPEG
# test_258.JPEG
# test_655.JPEG
# test_1948.JPEG
# test_1048.JPEG
# test_565.JPEG
# test_4842.JPEG
# test_1709.JPEG
# test_5005.JPEG
# test_8156.JPEG
# test_3437.JPEG
# test_9646.JPEG
# test_4427.JPEG
# test_6605.JPEG
# test_2175.JPEG
# test_7551.JPEG
# test_6660.JPEG
# test_9965.JPEG
# test_8513.JPEG
# test_3819.JPEG
# test_48.JPEG
# test_6495.JPEG
# test_9677.JPEG
# test_4784.JPEG
# test_6002.JPEG
# test_8531.JPEG
# test_1603.JPEG
# test_6669.JPEG
# test_9280.JPEG
# test_7771.JPEG
# test_3959.JPEG
# test_8045.JPEG
# test_9211.JPEG
# test_6027.JPEG
# test_6270.JPEG
# test_6584.JPEG
# test_7285.JPEG
# test_6289.JPEG
# test_977.JPEG
# test_7649.JPEG
# test_8817.JPEG
# test_3484.JPEG
# test_4093.JPEG
# test_2046.JPEG
# test_5142.JPEG
# test_1656.JPEG
# test_4515.JPEG
# test_270.JPEG
# test_8221.JPEG
# test_9199.JPEG
# test_1052.JPEG
# test_1834.JPEG
# test_2901.JPEG
# test_2148.JPEG
# test_7182.JPEG
# test_8059.JPEG
# test_3686.JPEG
# test_8439.JPEG
# test_2369.JPEG
# test_1210.JPEG
# test_9521.JPEG
# test_3619.JPEG
# test_5056.JPEG
# test_9023.JPEG
# test_3087.JPEG
# test_8580.JPEG
# test_4788.JPEG
# test_1915.JPEG
# test_672.JPEG
# test_2727.JPEG
# test_6851.JPEG
# test_7896.JPEG
# test_2728.JPEG
# test_8431.JPEG
# test_8687.JPEG
# test_1107.JPEG
# test_3439.JPEG
# test_2641.JPEG
# test_5310.JPEG
# test_6332.JPEG
# test_988.JPEG
# test_799.JPEG
# test_5072.JPEG
# test_1679.JPEG
# test_1773.JPEG
# test_2146.JPEG
# test_621.JPEG
# test_2923.JPEG
# test_2561.JPEG
# test_1684.JPEG
# test_4557.JPEG
# test_8981.JPEG
# test_5070.JPEG
# test_5609.JPEG
# test_6735.JPEG
# test_9241.JPEG
# test_2890.JPEG
# test_8515.JPEG
# test_1559.JPEG
# test_299.JPEG
# test_5918.JPEG
# test_2194.JPEG
# test_6797.JPEG
# test_7609.JPEG
# test_1557.JPEG
# test_6260.JPEG
# test_8608.JPEG
# test_687.JPEG
# test_6295.JPEG
# test_294.JPEG
# test_9098.JPEG
# test_6904.JPEG
# test_5160.JPEG
# test_6992.JPEG
# test_5783.JPEG
# test_9789.JPEG
# test_9916.JPEG
# test_1856.JPEG
# test_2854.JPEG
# test_2657.JPEG
# test_2537.JPEG
# test_2323.JPEG
# test_4269.JPEG
# test_307.JPEG
# test_205.JPEG
# test_867.JPEG
# test_8000.JPEG
# test_7139.JPEG
# test_5570.JPEG
# test_8859.JPEG
# test_2801.JPEG
# test_1733.JPEG
# test_635.JPEG
# test_7318.JPEG
# test_325.JPEG
# test_9045.JPEG
# test_6300.JPEG
# test_6568.JPEG
# test_4500.JPEG
# test_9781.JPEG
# test_7847.JPEG
# test_208.JPEG
# test_126.JPEG
# test_6982.JPEG
# test_6912.JPEG
# test_6621.JPEG
# test_2787.JPEG
# test_5629.JPEG
# test_3069.JPEG
# test_7484.JPEG
# test_1755.JPEG
# test_9958.JPEG
# test_8259.JPEG
# test_9079.JPEG
# test_7493.JPEG
# test_7908.JPEG
# test_3643.JPEG
# test_6640.JPEG
# test_7110.JPEG
# test_4635.JPEG
# test_8708.JPEG
# test_934.JPEG
# test_8354.JPEG
# test_844.JPEG
# test_9561.JPEG
# test_7850.JPEG
# test_4991.JPEG
# test_3627.JPEG
# test_295.JPEG
# test_3528.JPEG
# test_6927.JPEG
# test_4411.JPEG
# test_6989.JPEG
# test_759.JPEG
# test_4975.JPEG
# test_4087.JPEG
# test_5046.JPEG
# test_4205.JPEG
# test_4053.JPEG
# test_9652.JPEG
# test_9217.JPEG
# test_5292.JPEG
# test_6708.JPEG
# test_7596.JPEG
# test_4602.JPEG
# test_6442.JPEG
# test_2652.JPEG
# test_8709.JPEG
# test_2089.JPEG
# test_8696.JPEG
# test_2636.JPEG
# test_3320.JPEG
# test_6774.JPEG
# test_257.JPEG
# test_4287.JPEG
# test_4396.JPEG
# test_2292.JPEG
# test_2279.JPEG
# test_828.JPEG
# test_2439.JPEG
# test_261.JPEG
# test_4655.JPEG
# test_6984.JPEG
# test_4404.JPEG
# test_7755.JPEG

# %%
file
# Out:
# 'test_1246.JPEG'
